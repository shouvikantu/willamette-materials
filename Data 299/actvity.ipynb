# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import ConfusionMatrixDisplay as CMD
from sklearn.inspection import DecisionBoundaryDisplay as DBD
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('basic_labeling.csv')
df.head()
# Out:
#          x1        x2  label
# 0  1.120324  1.865762      0
# 1 -0.633758  0.177151      0
# 2 -1.131427  1.365351      1
# 3  1.067178  1.305026      0
# 4  1.199452  1.534949      0

# %%
plt.scatter(df['x1'], df['x2'], c=df.label)

# %%
train, test = train_test_split(df, test_size=0.3)
train
# Out:
#            x1        x2  label
# 193  1.771876 -0.862047      2
# 284  1.309011 -0.250917      2
# 175  0.252528  0.117483      0
# 146 -0.353571 -1.147471      2
# 368 -1.760694  0.280888      1
# ..        ...       ...    ...
# 277 -0.743523  0.934669      1
# 427  1.394105  1.758092      0
# 176 -0.150422 -0.084452      1
# 166 -0.668695  0.149208      1
# 278  0.126482 -1.275943      2
#
# [350 rows x 3 columns]

# %%
tree = DecisionTreeClassifier()
t_fit = tree.fit(train.iloc[:, :2], train['label'])

# %%
plot_tree(tree)
plt.savefig('decision_tree.png')
plt.show()

# %%
plt.savefig('decision_tree.png')
